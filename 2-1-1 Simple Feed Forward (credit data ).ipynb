# %%
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam

# %%
df = pd.read_csv("./data/credit_data.csv")
df.head()
# Out:
#    clientid        income        age         loan       LTI  default
# 0         1  66155.925095  59.017015  8106.532131  0.122537        0
# 1         2  34415.153966  48.117153  6564.745018  0.190752        0
# 2         3  57317.170063  63.108049  8020.953296  0.139940        0
# 3         4  42709.534201  45.751972  6103.642260  0.142911        0
# 4         5  66952.688845  18.584336  8770.099235  0.130989        1

# %%
features = df[["income", "age", "loan"]]
y = np.array(df.default).reshape(-1,1)

# %%
encoder = OneHotEncoder()
targets = encoder.fit_transform(y).toarray()

# %%
train_features, test_features, train_targets, test_targets = train_test_split(features, targets, test_size=0.2)

# %%
model = Sequential()
model.add(Dense(10, input_dim=3, activation='sigmoid'))
model.add(Dense(2, activation='softmax'))
# Out:
# C:\Users\Admin\keras\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer = Adam(learning_rate=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.fit(train_features, train_targets, epochs=5000, verbose=2)
results = model.evaluate(test_features, test_targets)
# Out:
# Epoch 1/5000
# 50/50 - 1s - 17ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 2/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 3/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 4/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 5/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4031
# Epoch 6/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 7/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 8/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 9/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 10/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 11/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 12/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 13/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 14/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 15/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 16/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 17/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 18/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 19/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 20/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4030
# Epoch 21/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 22/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 23/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 24/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 25/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 26/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 27/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 28/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 29/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 30/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 31/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 32/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 33/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 34/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 35/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 36/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 37/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 38/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 39/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 40/5000
# 50/50 - 0s - 6ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 41/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 42/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 43/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 44/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 45/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 46/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 47/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 48/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 49/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 50/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 51/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 52/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 53/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 54/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 55/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 56/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 57/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 58/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 59/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 60/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 61/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 62/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 63/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 64/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 65/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 66/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 67/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 68/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 69/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 70/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 71/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 72/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 73/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 74/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 75/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 76/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 77/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 78/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 79/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 80/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 81/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 82/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 83/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 84/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 85/5000
# 50/50 - 0s - 6ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 86/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 87/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 88/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 89/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 90/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 91/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 92/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 93/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 94/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 95/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 96/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 97/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 98/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 99/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 100/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 101/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 102/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 103/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 104/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 105/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 106/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 107/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4030
# Epoch 108/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 109/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4030
# Epoch 110/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 111/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 112/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 113/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 114/5000
# 50/50 - 0s - 5ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 115/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 116/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 117/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 118/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 119/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 120/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 121/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 122/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 123/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 124/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 125/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 126/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 127/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 128/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 129/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 130/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 131/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 132/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 133/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 134/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 135/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 136/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 137/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 138/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 139/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 140/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 141/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 142/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 143/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 144/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 145/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 146/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 147/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 148/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 149/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 150/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 151/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 152/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 153/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 154/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 155/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 156/5000
# 50/50 - 0s - 6ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 157/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 158/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 159/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 160/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 161/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 162/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 163/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 164/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 165/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 166/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 167/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 168/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 169/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 170/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 171/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 172/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 173/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 174/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 175/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 176/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 177/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 178/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 179/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 180/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 181/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 182/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 183/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 184/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 185/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 186/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 187/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 188/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 189/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 190/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 191/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 192/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 193/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 194/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 195/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 196/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 197/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 198/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 199/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 200/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 201/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 202/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 203/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 204/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 205/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 206/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 207/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 208/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 209/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 210/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 211/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 212/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 213/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 214/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 215/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 216/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 217/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 218/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 219/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 220/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 221/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 222/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 223/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 224/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 225/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 226/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 227/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 228/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 229/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 230/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 231/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 232/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 233/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 234/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 235/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 236/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 237/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 238/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 239/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 240/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 241/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 242/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 243/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 244/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 245/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 246/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 247/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 248/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 249/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 250/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 251/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 252/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4030
# Epoch 253/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 254/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 255/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 256/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 257/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 258/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 259/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 260/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 261/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 262/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 263/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 264/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 265/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 266/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 267/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 268/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 269/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 270/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 271/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 272/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 273/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4030
# Epoch 274/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 275/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 276/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 277/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 278/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 279/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 280/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 281/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 282/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 283/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 284/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 285/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 286/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 287/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 288/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 289/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 290/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 291/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 292/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 293/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 294/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 295/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4030
# Epoch 296/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 297/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 298/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 299/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 300/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 301/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 302/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 303/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 304/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 305/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 306/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 307/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 308/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 309/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 310/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 311/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 312/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 313/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 314/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 315/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 316/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 317/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 318/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 319/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 320/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 321/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 322/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 323/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 324/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 325/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 326/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 327/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 328/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 329/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 330/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 331/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 332/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 333/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 334/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 335/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 336/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 337/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 338/5000
# 50/50 - 0s - 5ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 339/5000
# 50/50 - 0s - 5ms/step - accuracy: 0.8612 - loss: 0.4030
# Epoch 340/5000
# 50/50 - 0s - 5ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 341/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 342/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 343/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 344/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 345/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 346/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 347/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 348/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 349/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 350/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 351/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 352/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 353/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 354/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 355/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 356/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 357/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 358/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 359/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 360/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 361/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 362/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 363/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 364/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 365/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 366/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 367/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 368/5000
# 50/50 - 0s - 3ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 369/5000
# 50/50 - 0s - 6ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 370/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 371/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 372/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 373/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 374/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 375/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 376/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 377/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 378/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 379/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 380/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 381/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 382/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 383/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 384/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 385/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 386/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 387/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 388/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 389/5000
# 50/50 - 0s - 4ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 390/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 391/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 392/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 393/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 394/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 395/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 396/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 397/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 398/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 399/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 400/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 401/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4030
# Epoch 402/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 403/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 404/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 405/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 406/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 407/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4027
# Epoch 408/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4029
# Epoch 409/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 410/5000
# 50/50 - 0s - 2ms/step - accuracy: 0.8612 - loss: 0.4028
# Epoch 411/5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 3
#       1 optimizer = Adam(learning_rate=0.0005)
#       2 model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# ----> 3 model.fit(train_features, train_targets, epochs=5000, verbose=2)
#       4 results = model.evaluate(test_features, test_targets)
#
# File ~\keras\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\keras\lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File ~\keras\lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File ~\keras\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\keras\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\keras\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\keras\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\keras\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\keras\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\keras\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\keras\lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~\keras\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
print(results)
# Out:
# [0.42792487144470215, 0.8475000262260437]
